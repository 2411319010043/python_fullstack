# %%
import numpy as np

# %% [markdown]
# ### 1. 多维性

# %%
arr = np.array(5)  # 创建0维的ndarray数组
print(arr)
print('arr的维度:', arr.ndim)  # 查看数组的维度
# Out:
# 5
# arr的维度: 0

# %%
arr = np.array([1, 2, 3])  # 创建1维的ndarray数组
print(arr)
print('arr的维度:', arr.ndim)  # 查看数组的维度
# Out:
# [1 2 3]
# arr的维度: 1

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])  # 创建2维的ndarray数组
print(arr)
print('arr的维度:', arr.ndim)  # 查看数组的维度
# Out:
# [[1 2 3]
#  [4 5 6]]
# arr的维度: 2

# %% [markdown]
# ### 2. 同质性

# %%
arr = np.array([1, 'hello'])  # 不同的数据类型会被强制转换成相同的数据类型
print(arr)  # 将 1 --> '1'
# Out:
# ['1' 'hello']

# %%
arr = np.array([1, 2.5])  # 不同的数据类型会被强制转换成相同的数据类型
print(arr)  # 将 [1.  2.5]
# Out:
# [1.   2.54]
