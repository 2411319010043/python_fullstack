# %%
import numpy as np

# %% [markdown]
# bool 布尔类型
# int 整数类型 uint
# float 浮点数
# complex 复数

# %%
arr = np.array([1,0,3,1], dtype=np.bool)
print(arr)
# Out:
# [ True False  True  True]

# %%
arr = np.array([1,0,127,1], dtype=np.int8)
print(arr)
# Out:
# [  1   0 127   1]
